# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as pltF
import seaborn as sns
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat

# %%
df = pd.read_csv('data.csv')
del df['Unnamed: 0']
df
# Out:
#                        Name  Age          Nationality  Overall  Potential  \
# 0                  L. Messi   31            Argentina       94         94
# 1         Cristiano Ronaldo   33             Portugal       94         94
# 2                 Neymar Jr   26               Brazil       92         93
# 3                    De Gea   27                Spain       91         93
# 4              K. De Bruyne   27              Belgium       91         92
# 5                 E. Hazard   27              Belgium       91         91
# 6                 L. Modrić   32              Croatia       91         91
# 7                 L. Suárez   31              Uruguay       91         91
# 8              Sergio Ramos   32                Spain       91         91
# 9                  J. Oblak   25             Slovenia       90         93
# 10           R. Lewandowski   29               Poland       90         90
# 11                 T. Kroos   28              Germany       90         90
# ...

# %%
# je regarde mes NaN
df.isna().sum()
# Out:
# Name                        0
# Age                         0
# Nationality                 0
# Overall                     0
# Potential                   0
# Club                        0
# Value                       0
# Preferred Foot              0
# International Reputation    0
# Weak Foot                   0
# Skill Moves                 0
# Work Rate                   0
# Position                    0
# Jersey Number               0
# Joined                      0
# Contract Valid Until        0
# Height                      0
# Weight                      0
# Crossing                    0
# Finishing                   0
# HeadingAccuracy             0
# ShortPassing                0
# Dribbling                   0
# BallControl                 0
# Acceleration                0
# SprintSpeed                 0
# ShotPower                   0
# Jumping                     0
# Stamina                     0
# Strength                    0
# Aggression                  0
# ...

# %%
#je supprine les dropna de la collone
df=df.dropna(subset=['Club'])
df=df.dropna(subset=['Contract Valid Until'])

# %%
#je mets tout les indexes dans une variable
i = df[(df['Joined'].isna())&(df['Contract Valid Until'])]['Joined'].index

# %%
df[['Joined']]
# Out:
#           Joined
# 0     2004-07-01
# 1     2018-07-10
# 2     2017-08-03
# 3     2011-07-01
# 4     2015-08-30
# 5     2012-07-01
# 6     2012-08-01
# 7     2014-07-11
# 8     2005-08-01
# 9     2014-07-16
# 10    2014-07-01
# 11    2014-07-17
# 12    2010-08-04
# 13    2010-07-14
# 14    2016-07-16
# 15    2015-07-01
# 16    2010-07-01
# 17    2014-07-28
# 18    2014-07-01
# 19    2018-08-09
# 20    2008-09-01
# 21    2013-07-16
# 22    2011-07-01
# 23    2011-07-28
# 24    2005-07-01
# 25    2018-07-01
# 26    2017-07-01
# 27    2013-07-11
# 28    1972-09-09
# 29    2010-07-01
# ...          ...
# 18177 2016-12-06
# 18178 2018-04-04
# 18179 2018-07-01
# 18180 2013-07-01
# 18181 2017-01-01
# 18182 2018-09-08
# 18183 2018-08-17
# 18184 2017-11-04
# 18185 2018-02-23
# 18186 2016-07-11
# 18187 2017-07-01
# 18188 2017-07-01
# 18189 2017-07-01
# 18190 2018-07-01
# 18191 2018-07-01
# 18192 2018-01-01
# 18193 2018-01-01
# 18194 2018-07-01
# 18195 2018-03-16
# 18196 2017-07-01
# ...

# %%
#changer les Nan en dates
df['Joined']=df['Joined'].fillna("1972-09-09")

# %%
# je change la colonnes en data time
df['Joined'] = pd.to_datetime(df['Joined'],infer_datetime_format=True)

# %%
df['Contract Valid Until'] = pd.to_datetime(df['Contract Valid Until'],infer_datetime_format=True)

# %%
#je change le tout en timestamp
df['Joined'].map(lambda x : x.strftime("%s"))
# Out:
# 0        1088632800
# 1        1531173600
# 2        1501711200
# 3        1309471200
# 4        1440885600
# 5        1341093600
# 6        1343772000
# 7        1405029600
# 8        1122847200
# 9        1405461600
# 10       1404165600
# 11       1405548000
# 12       1280872800
# 13       1279058400
# 14       1468620000
# 15       1435701600
# 16       1277935200
# 17       1406498400
# 18       1404165600
# 19       1533765600
# 20       1220220000
# 21       1373925600
# 22       1309471200
# 23       1311804000
# 24       1120168800
# 25       1530396000
# 26       1498860000
# 27       1373493600
# 28         84841200
# 29       1277935200
#             ...
# 18177    1480978800
# 18178    1522792800
# 18179    1530396000
# 18180    1372629600
# 18181    1483225200
# 18182    1536357600
# 18183    1534456800
# 18184    1509750000
# 18185    1519340400
# 18186    1468188000
# 18187    1498860000
# 18188    1498860000
# 18189    1498860000
# 18190    1530396000
# ...

# %%
#changer le df en timestamp
df['Contract Valid Until'].map(lambda x : x.strftime("%s"))
# Out:
# 0        1609455600
# 1        1640991600
# 2        1640991600
# 3        1577833200
# 4        1672527600
# 5        1577833200
# 6        1577833200
# 7        1609455600
# 8        1577833200
# 9        1609455600
# 10       1609455600
# 11       1640991600
# 12       1546297200
# 13       1577833200
# 14       1672527600
# 15       1640991600
# 16       1704063600
# 17       1672527600
# 18       1640991600
# 19       1704063600
# 20       1672527600
# 21       1577833200
# 22       1609455600
# 23       1609455600
# 24       1577833200
# 25       1640991600
# 26       1672527600
# 27       1609455600
# 28       1561845600
# 29       1640991600
#             ...
# 18177    1546297200
# 18178    1514761200
# 18179    1577833200
# 18180    1546297200
# 18181    1514761200
# 18182    1609455600
# 18183    1672527600
# 18184    1609455600
# 18185    1514761200
# 18186    1546297200
# 18187    1577833200
# 18188    1609455600
# 18189    1577833200
# 18190    1609455600
# ...

# %%
df['Contract Valid Until'] = df['Contract Valid Until'].map(lambda x : x.strftime("%s"))
df['Joined'] = df['Joined'].map(lambda x : x.strftime("%s"))

# %%
# je fais mon masque
#je prend tout les Nan de ma collone par rapport à une autre
#j'utilise lambda pour prendre l'année et la changer
df['Contract Valid Until'].loc[i].map(lambda x : float(x)-63072000)
# Out:
# 28       1.498774e+09
# 38       1.498774e+09
# 91       1.498774e+09
# 166      1.483139e+09
# 176      1.498774e+09
# 332      1.498774e+09
# 354      1.498774e+09
# 357      1.498774e+09
# 427      1.498774e+09
# 434      1.498774e+09
# 437      1.498774e+09
# 444      1.498774e+09
# 460      1.498774e+09
# 496      1.498774e+09
# 504      1.498774e+09
# 562      1.498774e+09
# 569      1.498774e+09
# 601      1.498774e+09
# 609      1.498774e+09
# 617      1.498774e+09
# 620      1.527804e+09
# 702      1.498774e+09
# 730      1.530396e+09
# 732      1.498774e+09
# 779      1.498774e+09
# 782      1.530396e+09
# 794      1.498774e+09
# 802      1.483139e+09
# 809      1.498774e+09
# 823      1.498774e+09
#              ...
# 16922    1.498774e+09
# 16950    1.498774e+09
# 16985    1.498774e+09
# 16999    1.498774e+09
# 17019    1.498774e+09
# 17053    1.484867e+09
# 17069    1.483225e+09
# 17130    1.498774e+09
# 17168    1.498774e+09
# 17195    1.483571e+09
# ...

# %%
#puis je mets tout dans la collones ciblé
df['Joined'].loc[i] = df['Contract Valid Until'].loc[i].map(lambda x : float(x)-63072000)
# Out:
# /home/funnyeoman/anaconda3/envs/dev/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df['Value'] = df['Value'].str.replace("€","").str.replace('M',"000000").str.replace("K","000").str.replace(".","")

# %%
df['Height'] = df['Height'].str.replace("'",".")
df['Height'] = df['Height'].astype(float)

# %%
df['Height'] = df['Height']*0.3048

# %%
df['Height']
# Out:
# 0        1.737360
# 1        1.889760
# 2        1.798320
# 3        1.950720
# 4        1.557528
# 5        1.767840
# 6        1.767840
# 7        1.828800
# 8        1.828800
# 9        1.889760
# 10       1.828800
# 11       1.828800
# 12       1.889760
# 13       1.767840
# 14       1.706880
# 15       1.554480
# 16       1.889760
# 17       1.798320
# 18       1.889760
# 19       2.011680
# 20       1.889760
# 21       1.859280
# 22       1.950720
# 23       1.767840
# 24       1.889760
# 25       1.554480
# 26       1.798320
# 27       1.859280
# 28       1.557528
# 29       1.645920
#            ...
# 18177    1.554480
# 18178    1.828800
# 18179    1.889760
# 18180    1.859280
# 18181    1.557528
# 18182    1.554480
# 18183    1.889760
# 18184    1.859280
# 18185    1.557528
# 18186    1.554480
# 18187    1.554480
# 18188    1.554480
# 18189    1.554480
# 18190    1.798320
# 18191    1.557528
# 18192    1.859280
# 18193    1.767840
# 18194    1.920240
# 18195    1.767840
# ...

# %%
df['Weight'] = df['Weight'].str.replace("lbs","")
df['Weight'] = df['Weight'].astype(float)
df['Weight'] = df['Weight']*0.453592

# %%
df['Joined']  = df['Joined'] .astype(int)               
df['Contract Valid Until'] = df['Contract Valid Until'].astype(int)

# %%
df['Club']
# Out:
# 0                  FC Barcelona
# 1                      Juventus
# 2           Paris Saint-Germain
# 3             Manchester United
# 4               Manchester City
# 5                       Chelsea
# 6                   Real Madrid
# 7                  FC Barcelona
# 8                   Real Madrid
# 9               Atlético Madrid
# 10            FC Bayern München
# 11                  Real Madrid
# 12              Atlético Madrid
# 13              Manchester City
# 14                      Chelsea
# 15                     Juventus
# 16            Tottenham Hotspur
# 17              Atlético Madrid
# 18                 FC Barcelona
# 19                  Real Madrid
# 20                 FC Barcelona
# 21          Paris Saint-Germain
# 22            FC Bayern München
# 23              Manchester City
# 24                     Juventus
# 25          Paris Saint-Germain
# 26                    Liverpool
# 27                  Real Madrid
# 28            FC Bayern München
# ...

# %%
df['Work Rate']
# Out:
# 0        Medium/ Medium
# 1             High/ Low
# 2          High/ Medium
# 3        Medium/ Medium
# 4            High/ High
# 5          High/ Medium
# 6            High/ High
# 7          High/ Medium
# 8          High/ Medium
# 9        Medium/ Medium
# 10         High/ Medium
# 11       Medium/ Medium
# 12         Medium/ High
# 13         High/ Medium
# 14         Medium/ High
# 15         High/ Medium
# 16           High/ High
# 17           High/ High
# 18       Medium/ Medium
# 19       Medium/ Medium
# 20       Medium/ Medium
# 21           High/ High
# 22       Medium/ Medium
# 23         High/ Medium
# 24         Medium/ High
# 25         High/ Medium
# 26         High/ Medium
# 27         Medium/ High
# 28       Medium/ Medium
# 29         High/ Medium
#               ...
# 18177    Medium/ Medium
# 18178    Medium/ Medium
# 18179    Medium/ Medium
# 18180    Medium/ Medium
# 18181    Medium/ Medium
# 18182       Low/ Medium
# 18183    Medium/ Medium
# ...

# %%
col= ['Nationality','Club','Preferred Foot','Work Rate','Position']
dico = []
for elem in col :
    liste = df[elem].unique()
    list_val = range(len(df[elem].unique()))
    df[elem] = 
    d1 = dict(zip(liste,list_val))
    dico.append(d1)

# %%
d = dict(zip(col,dico))

# %%
# Out:
# {'Nationality': {'Argentina': 0,
#   'Portugal': 1,
#   'Brazil': 2,
#   'Spain': 3,
#   'Belgium': 4,
#   'Croatia': 5,
#   'Uruguay': 6,
#   'Slovenia': 7,
#   'Poland': 8,
#   'Germany': 9,
#   'France': 10,
#   'England': 11,
#   'Italy': 12,
#   'Egypt': 13,
#   'Colombia': 14,
#   'Denmark': 15,
#   'Gabon': 16,
#   'Wales': 17,
#   'Senegal': 18,
#   'Costa Rica': 19,
#   'Slovakia': 20,
#   'Netherlands': 21,
#   'Bosnia Herzegovina': 22,
#   'Morocco': 23,
#   'Serbia': 24,
#   'Algeria': 25,
#   'Austria': 26,
#   'Greece': 27,
#   'Chile': 28,
#   'Sweden': 29,
#   'Korea Republic': 30,
#   'Finland': 31,
#   'Guinea': 32,
#   'Montenegro': 33,
#   'Armenia': 34,
#   'Switzerland': 35,
#   'Norway': 36,
#   'Czech Republic': 37,
#   'Scotland': 38,
#   'Ghana': 39,
#   'Central African Rep.': 40,
#   'DR Congo': 41,
#   'Ivory Coast': 42,
#   'Russia': 43,
#   'Ukraine': 44,
#   'Iceland': 45,
#   'Mexico': 46,
#   'Jamaica': 47,
#   'Albania': 48,
#   'Venezuela': 49,
# ...

# %%
range(len(df['Nationality'].unique()))
# Out:
# range(0, 163)
